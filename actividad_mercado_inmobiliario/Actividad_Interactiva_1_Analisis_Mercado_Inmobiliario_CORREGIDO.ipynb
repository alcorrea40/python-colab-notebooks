# %% [markdown]
# <a href="https://colab.research.google.com/github/alcorrea40/python-colab-notebooks/blob/main/Actividad_Interactiva_1_Analisis_Mercado_Inmobiliario_CORREGIDO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🏡 Actividad Interactiva #1: Caso de análisis del mercado inmobiliario

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 📥 Carga del dataset 'AmesHousing_corregido.csv'

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-3d6713a8-531b-4d72-b6f0-8d4dbbbf09e9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3d6713a8-531b-4d72-b6f0-8d4dbbbf09e9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('AmesHousing_corregido.csv')
df.head()
# Out:
#    SalePrice  GrLivArea  YearBuilt Neighborhood  GarageCars  GarageArea
# 0     215000       1710       2003      CollgCr           2         548
# 1     105000       1262       1976      Veenker           2         460
# 2     172000       1786       2001      CollgCr           2         608
# 3     244000       1717       1915      Crawfor           3         642
# 4     189000       2198       2000      NoRidge           3         836

# %% [markdown]
# ## 📊 Revisión inicial del dataset

# %%
df.info()
df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SalePrice     5 non-null      int64
#  1   GrLivArea     5 non-null      int64
#  2   YearBuilt     5 non-null      int64
#  3   Neighborhood  5 non-null      object
#  4   GarageCars    5 non-null      int64
#  5   GarageArea    5 non-null      int64
# dtypes: int64(5), object(1)
# memory usage: 372.0+ bytes
#             SalePrice    GrLivArea    YearBuilt Neighborhood  GarageCars  \
# count        5.000000     5.000000     5.000000            5    5.000000
# unique            NaN          NaN          NaN            4         NaN
# top               NaN          NaN          NaN      CollgCr         NaN
# freq              NaN          NaN          NaN            2         NaN
# mean    185000.000000  1734.600000  1979.000000          NaN    2.400000
# ...

# %% [markdown]
# ## 🧹 Limpieza de datos

# %%
# Ya contiene columnas necesarias sin nulos en este ejemplo

# %% [markdown]
# ## 📈 Análisis univariado de variables clave

# %%
sns.histplot(df['SalePrice'], kde=True)
plt.title('Distribución del Precio de Venta')
plt.show()

# %%
sns.histplot(df['GrLivArea'], kde=True)
plt.title('Área Habitable sobre el Nivel del Suelo')
plt.show()

# %% [markdown]
# ## 🔍 Análisis bivariado

# %%
sns.scatterplot(x='GrLivArea', y='SalePrice', data=df)
plt.title('Precio vs Área Habitable')
plt.show()

# %%
sns.boxplot(x='Neighborhood', y='SalePrice', data=df)
plt.xticks(rotation=90)
plt.title('Precio por Vecindario')
plt.show()

# %% [markdown]
# ## 🔗 Mapa de calor de correlaciones entre variables numéricas

# %%
corr = df.corr(numeric_only=True)
sns.heatmap(corr[['SalePrice']].sort_values('SalePrice', ascending=False), annot=True, cmap='coolwarm')
plt.title('Correlación con Precio de Venta')
plt.show()

# %% [markdown]
# ## ✏️ Reflexión
# - ¿Qué variables se relacionan más fuertemente con el precio?
# - ¿Qué patrones podrías usar para crear un modelo predictivo?
# - ¿Cómo comunicarías estos hallazgos a un cliente o directivo?

# %% [markdown]
# ## 🧠 Isla cognitiva
# > En la vida profesional, los datos de vivienda, salud, comercio o clima son fuente constante de análisis económico y social.

# %% [markdown]
# ## 🔗 Párrafo conector
# Ahora estructuraremos todo en un informe narrativo que puedas usar como evidencia de tus capacidades analíticas.

# %% [markdown]
# ## 📚 Bibliografía
# > McKinney, W. (2022). *Python for Data Analysis*. O’Reilly Media.
