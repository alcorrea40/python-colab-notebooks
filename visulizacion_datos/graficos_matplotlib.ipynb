# %% [markdown]
# <a href="https://colab.research.google.com/github/alcorrea40/python-colab-notebooks/blob/main/graficos_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📊 Visualización de datos con matplotlib
# Este notebook te enseña a crear gráficos de líneas, barras y dispersión usando `matplotlib.pyplot`, personalizando títulos, etiquetas y estilos.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files

# Subir archivo CSV
uploaded = files.upload()

# Leer archivo
df = pd.read_csv("datos_graficos.csv")
df
# Out:
#      <input type="file" id="files-aa51906b-2c8b-4568-916d-61d1e8ee3fbc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-aa51906b-2c8b-4568-916d-61d1e8ee3fbc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## 📈 Gráfico de líneas

# %%
plt.plot(df['Mes'], df['Ventas'], marker='o', label='Ventas')
plt.plot(df['Mes'], df['Gastos'], marker='s', label='Gastos')
plt.title('Ventas y Gastos Mensuales')
plt.xlabel('Mes')
plt.ylabel('Valor en USD')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 📊 Gráfico de barras

# %%
plt.bar(df['Mes'], df['Ventas'], color='skyblue')
plt.title('Ventas por Mes')
plt.xlabel('Mes')
plt.ylabel('Ventas (USD)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 🔵 Gráfico de dispersión

# %%
plt.scatter(df['Ventas'], df['Gastos'], color='red')
plt.title('Relación entre Ventas y Gastos')
plt.xlabel('Ventas')
plt.ylabel('Gastos')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 🧪 Ejercicio práctico

# %%
# Crea un gráfico combinado de barras para ventas y gastos
import numpy as np
ancho = 0.35
x = np.arange(len(df['Mes']))

plt.bar(x - ancho/2, df['Ventas'], width=ancho, label='Ventas')
plt.bar(x + ancho/2, df['Gastos'], width=ancho, label='Gastos')

plt.xlabel('Mes')
plt.ylabel('USD')
plt.title('Comparación de Ventas y Gastos')
plt.xticks(x, df['Mes'], rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
print("🎉 ¡Has completado tu exploración de gráficos con matplotlib!")
# Out:
# 🎉 ¡Has completado tu exploración de gráficos con matplotlib!
