# %% [markdown]
# <a href="https://colab.research.google.com/github/alcorrea40/python-colab-notebooks/blob/main/Actividad_Interactiva_1_Cargar_y_Explorar_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐼 Actividad Interactiva #1: Cargar y explorar datos con pandas

# %%
import pandas as pd

# %% [markdown]
# ## 📂 Cargar archivo CSV desde tu equipo

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-90f5ffd4-6baa-447c-bf1f-89e4d07e31eb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-90f5ffd4-6baa-447c-bf1f-89e4d07e31eb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Reemplaza 'data.csv' con el nombre correcto si cambia
df = pd.read_csv('data.csv')

# %% [markdown]
# ## 🔍 Explora los datos con funciones básicas de pandas

# %%
df.head()
# Out:
#    Nombre  Edad    Ciudad  Ingreso_Mensual
# 0     Ana  23.0    Bogotá           2500.0
# 1    Luis  35.0  Medellín           3200.0
# 2  Carlos  45.0      Cali           2900.0
# 3   María  32.0    Bogotá              NaN
# 4   Sofía   NaN      Cali           3100.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Nombre           5 non-null      object
#  1   Edad             4 non-null      float64
#  2   Ciudad           5 non-null      object
#  3   Ingreso_Mensual  4 non-null      float64
# dtypes: float64(2), object(2)
# memory usage: 292.0+ bytes

# %%
df.describe()
# Out:
#             Edad  Ingreso_Mensual
# count   4.000000         4.000000
# mean   33.750000      2925.000000
# std     9.069179       309.569594
# min    23.000000      2500.000000
# 25%    29.750000      2800.000000
# 50%    33.500000      3000.000000
# 75%    37.500000      3125.000000
# max    45.000000      3200.000000

# %% [markdown]
# ## ✏️ Reflexión
# Responde estas preguntas:
# - ¿Cuántas columnas tiene el dataset?
# - ¿Qué tipo de variables contiene?
# - ¿Hay valores nulos? ¿Dónde se observan?
# - ¿Qué podrías hacer para tratarlos más adelante?

# %%
# Escribe tus respuestas aquí:
respuesta_1 = ""
respuesta_2 = ""

# %% [markdown]
# ## 🧠 Isla cognitiva
# > pandas permite convertir datos sin estructura en tabulaciones que pueden analizarse fácilmente.

# %% [markdown]
# ## 🔗 Párrafo conector
# Ahora que sabes explorar datos, es momento de aprender a seleccionar, filtrar y acceder a columnas y filas específicas en pandas.

# %% [markdown]
# ## 📚 Bibliografía
# > McKinney, W. (2022). *Python for Data Analysis*. O’Reilly Media.
