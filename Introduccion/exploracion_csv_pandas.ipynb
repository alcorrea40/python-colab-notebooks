# %% [markdown]
# <a href="https://colab.research.google.com/github/alcorrea40/python-colab-notebooks/blob/main/exploracion_csv_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📓 Exploración inicial de datos con pandas
# Este notebook te guía para:
# - Importar la librería `pandas`
# - Leer un archivo `.csv`
# - Explorar los datos con `head()`, `info()` y `describe()`

# %%
import pandas as pd
print("Librería pandas importada.")
# Out:
# Librería pandas importada.

# %% [markdown]
# ## 📥 Cargar archivo CSV
# Sube el archivo `data.csv` cuando se te solicite:

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-27a7582b-cade-430f-9183-8047c763d94e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-27a7582b-cade-430f-9183-8047c763d94e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("data.csv")
print("Archivo cargado correctamente.")
# Out:
# Archivo cargado correctamente.

# %% [markdown]
# ## 🔍 Primer vistazo a los datos

# %%
df.head()
# Out:
#    Nombre  Edad        Ciudad  Salario
# 0     Ana  23.0        Bogotá     2500
# 1    Luis  31.0      Medellín     3200
# 2  Carlos  19.0          Cali     1800
# 3   María  27.0  Barranquilla     2900
# 4   Sofía   NaN        Bogotá     3100

# %% [markdown]
# ## ℹ️ Información general del dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Nombre   5 non-null      object
#  1   Edad     4 non-null      float64
#  2   Ciudad   5 non-null      object
#  3   Salario  5 non-null      int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 292.0+ bytes

# %% [markdown]
# ## 📊 Estadísticas descriptivas

# %%
df.describe()
# Out:
#             Edad      Salario
# count   4.000000     5.000000
# mean   25.000000  2700.000000
# std     5.163978   570.087713
# min    19.000000  1800.000000
# 25%    22.000000  2500.000000
# 50%    25.000000  2900.000000
# 75%    28.000000  3100.000000
# max    31.000000  3200.000000

# %% [markdown]
# ## 🧪 Actividad guiada
# Responde con código:
# 1. ¿Cuántos valores nulos hay en la columna 'Edad'?
# 2. ¿Qué tipo de variable es 'Ciudad'?
# 3. ¿Cuál es el salario promedio?

# %%
print("Valores nulos en 'Edad':", df["Edad"].isnull().sum())
print("Tipo de dato de 'Ciudad':", df["Ciudad"].dtype)
print("Salario promedio:", df["Salario"].mean())
# Out:
# Valores nulos en 'Edad': 1
# Tipo de dato de 'Ciudad': object
# Salario promedio: 2700.0

# %%
print("¡Buen trabajo! Ahora sabes cómo importar pandas, leer un CSV y explorar un dataset.")
# Out:
# ¡Buen trabajo! Ahora sabes cómo importar pandas, leer un CSV y explorar un dataset.
